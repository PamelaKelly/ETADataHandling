# %% [markdown]
# # Data Analysis for Dublin Bus Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages
import datetime
import time

# %%
% time df = pd.read_csv('2012_one_week.csv')
# Out:
# Wall time: 18 s

# %%
df.head(5)
# Out:
#    Unnamed: 0         Timestamp  Line_ID  Direction JourneyPattern_ID  \
# 0           0  1352160002000000     41.0          0          041B0002
# 1           1  1352160002000000     27.0          0          00270001
# 2           2  1352160002000000    140.0          0          01400001
# 3           3  1352160002000000     83.0          0          083A0001
# 4           4  1352160002000000     16.0          0          016C0001
#
#    Time_Frame  VehicleJourney_ID Operator  Congestion  Longitude   Latitude  \
# 0  2012-11-05                 61       SL           0  -6.264167  53.453217
# 1  2012-11-05               4976       RD           0  -6.290833  53.319332
# 2  2012-11-05               6615       HN           0  -6.276083  53.343884
# 3  2012-11-05               7099       HN           0  -6.273733  53.419632
# 4  2012-11-05               6175       SL           0  -6.254583  53.355534
#
#    Delay  Block_ID  Vehicle_ID  Stop_ID  At_Stop      Time      Day  \
# 0   -623     41008       33631     3874        1  00:00:02  Tuesday
# 1      0     27011       33415     2355        1  00:00:02  Tuesday
# 2      0    140010       33141      895        1  00:00:02  Tuesday
# 3      0     83002       40019      324        1  00:00:02  Tuesday
# 4    -23     16017       33633      270        1  00:00:02  Tuesday
#
#                   datetime
# 0  ('00:00:02', 'Tuesday')
# 1  ('00:00:02', 'Tuesday')
# 2  ('00:00:02', 'Tuesday')
# 3  ('00:00:02', 'Tuesday')
# 4  ('00:00:02', 'Tuesday')

# %%
df.drop(df.columns[[0]], axis=1, inplace=True)
df.dtypes
# Out:
# Timestamp              int64
# Line_ID              float64
# Direction              int64
# JourneyPattern_ID     object
# Time_Frame            object
# VehicleJourney_ID      int64
# Operator              object
# Congestion             int64
# Longitude            float64
# Latitude             float64
# Delay                  int64
# Block_ID               int64
# Vehicle_ID             int64
# Stop_ID                int64
# At_Stop                int64
# Time                  object
# Day                   object
# datetime              object
# dtype: object

# %%
df.head(3)
# Out:
#           Timestamp  Line_ID  Direction JourneyPattern_ID  Time_Frame  \
# 0  1352160002000000     41.0          0          041B0002  2012-11-05
# 1  1352160002000000     27.0          0          00270001  2012-11-05
# 2  1352160002000000    140.0          0          01400001  2012-11-05
#
#    VehicleJourney_ID Operator  Congestion  Longitude   Latitude  Delay  \
# 0                 61       SL           0  -6.264167  53.453217   -623
# 1               4976       RD           0  -6.290833  53.319332      0
# 2               6615       HN           0  -6.276083  53.343884      0
#
#    Block_ID  Vehicle_ID  Stop_ID  At_Stop      Time      Day  \
# 0     41008       33631     3874        1  00:00:02  Tuesday
# 1     27011       33415     2355        1  00:00:02  Tuesday
# 2    140010       33141      895        1  00:00:02  Tuesday
#
#                   datetime
# 0  ('00:00:02', 'Tuesday')
# 1  ('00:00:02', 'Tuesday')
# 2  ('00:00:02', 'Tuesday')

# %%
df['Timestamp'] = df['Timestamp']//1000000

# %%
df.head(3)
# Out:
#     Timestamp  Line_ID  Direction JourneyPattern_ID  Time_Frame  \
# 0  1352160002     41.0          0          041B0002  2012-11-05
# 1  1352160002     27.0          0          00270001  2012-11-05
# 2  1352160002    140.0          0          01400001  2012-11-05
#
#    VehicleJourney_ID Operator  Congestion  Longitude   Latitude  Delay  \
# 0                 61       SL           0  -6.264167  53.453217   -623
# 1               4976       RD           0  -6.290833  53.319332      0
# 2               6615       HN           0  -6.276083  53.343884      0
#
#    Block_ID  Vehicle_ID  Stop_ID  At_Stop      Time      Day  \
# 0     41008       33631     3874        1  00:00:02  Tuesday
# 1     27011       33415     2355        1  00:00:02  Tuesday
# 2    140010       33141      895        1  00:00:02  Tuesday
#
#                   datetime
# 0  ('00:00:02', 'Tuesday')
# 1  ('00:00:02', 'Tuesday')
# 2  ('00:00:02', 'Tuesday')

# %%
df.shape
# Out:
# (2337254, 18)

# %%
# defining the categorical columns
categorical_columns = df[['JourneyPattern_ID', 'VehicleJourney_ID', 'Stop_ID', 'Day']].columns

# convert the types of these columns to category
for column in categorical_columns:
    df[column] = df[column].astype('category')

# %%
# prepare a table of descriptive statistics for categorical features
df[categorical_columns].describe().T
# Out:
#                      count unique       top    freq
# JourneyPattern_ID  2337224    472  046A1001   59284
# VehicleJourney_ID  2337254  17323      6059    1528
# Stop_ID            2337254   4563      2039   43374
# Day                2337254      7    Monday  395784

# %%
# delete all rows wchih are not in a journey and not at stop ? 
df_groupby=df.groupby(['VehicleJourney_ID', 'JourneyPattern_ID'])

size = df_groupby.size()

keys = df_groupby.groups

# %%
# cut out journeys that don't have enough entries to have even left the terminus? 
df2 = df_groupby.filter(lambda x: len(x) < 13) # figure out what this line does

# %%
df = pd.concat([df, df2]).drop_duplicates(keep=False) 
# keep = False doesn't keep
# any of the duplicates? Should we not keep the first or last so we have one entry
# for that instance at least?

# %%
df.shape
# Out:
# (2298944, 18)

# %% [markdown]
# ## Add a new feature for calculating time from terminus

# %%
# calculate the trip time in seconds 
zscore = lambda x: (x - x.min()) # figure out what this code does
df['Trip_Time'] = df.groupby(['VehicleJourney_ID', 'JourneyPattern_ID', 'Day'])['Timestamp'].transform(zscore)

# %%
df.tail(5)
# Out:
#           Timestamp  Line_ID  Direction JourneyPattern_ID  Time_Frame  \
# 2337249  1352764792     38.0          0          00381003  2012-11-12
# 2337250  1352764792     37.0          0          00371002  2012-11-12
# 2337251  1352764792     46.0          0          046A0001  2012-11-12
# 2337252  1352764796     16.0          0          00161001  2012-11-12
# 2337253  1352764798      7.0          0          00070001  2012-11-12
#
#         VehicleJourney_ID Operator  Congestion  Longitude   Latitude  Delay  \
# 2337249              1243       PO           0  -6.261583  53.352734   -188
# 2337250              2115       PO           0  -6.260700  53.347198   -249
# 2337251              7345       D2           0  -6.231650  53.318817      0
# 2337252              5652       SL           0  -6.218033  53.425232   -488
# 2337253              6963       D1           0  -6.138767  53.276184   -128
#
#          Block_ID  Vehicle_ID Stop_ID  At_Stop      Time     Day  \
# 2337249     38003       36045     265        1  23:59:52  Monday
# 2337250     37003       33578     313        1  23:59:52  Monday
# 2337251     46011       36020    2039        1  23:59:52  Monday
# 2337252     16004       33425    7347        1  23:59:56  Monday
# 2337253      7014       43007    2040        1  23:59:58  Monday
#
#                        datetime  Trip_Time
# 2337249  ('23:59:52', 'Monday')       2089
# 2337250  ('23:59:52', 'Monday')       1325
# 2337251  ('23:59:52', 'Monday')       4928
# 2337252  ('23:59:56', 'Monday')       4371
# 2337253  ('23:59:58', 'Monday')       1319

# %%
df_15744=df.loc[df['VehicleJourney_ID'] == 15744]

# %%
df_15744[categorical_columns].describe().T
# Out:
#                   count unique       top freq
# JourneyPattern_ID    77      1  07471001   77
# VehicleJourney_ID    77      1     15744   77
# Stop_ID              77      6      4319   41
# Day                  77      1    Sunday   77

# %% [markdown]
# ## Check the data for one VehicleJourney_ID 6187

# %%
df_6187 = df.loc[df.VehicleJourney_ID==6187]

# %%
df_6187[categorical_columns].describe().T
# Out:
#                   count unique       top freq
# JourneyPattern_ID   397      1  00270001  397
# VehicleJourney_ID   397      1      6187  397
# Stop_ID             397     74      2355   57
# Day                 397      5  Thursday   97

# %%
pd.unique(df_6187.JourneyPattern_ID.ravel()) # what does ravel do?
# Out:
# array(['00270001'], dtype=object)

# %%
pd.unique(df_6187.Day.ravel())
# Out:
# array(['Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Monday'], dtype=object)

# %%
df_6187_Mon = df_6187.loc[df_6187['Day'] == 'Monday']

# %%
df_6187_Mon[categorical_columns].describe().T
# Out:
#                   count unique       top freq
# JourneyPattern_ID    80      1  00270001   80
# VehicleJourney_ID    80      1      6187   80
# Stop_ID              80     50      4595   17
# Day                  80      1    Monday   80

# %%
df_6187_Mon.shape
# Out:
# (80, 19)

# %%
df_6187_Mon
# Out:
#           Timestamp  Line_ID  Direction JourneyPattern_ID  Time_Frame  \
# 2155470  1352733307     27.0          0          00270001  2012-11-12
# 2155599  1352733328     27.0          0          00270001  2012-11-12
# 2155711  1352733346     27.0          0          00270001  2012-11-12
# 2155833  1352733367     27.0          0          00270001  2012-11-12
# 2155974  1352733389     27.0          0          00270001  2012-11-12
# 2156083  1352733406     27.0          0          00270001  2012-11-12
# 2156345  1352733449     27.0          0          00270001  2012-11-12
# 2156489  1352733467     27.0          0          00270001  2012-11-12
# 2156583  1352733488     27.0          0          00270001  2012-11-12
# 2156706  1352733506     27.0          0          00270001  2012-11-12
# 2156853  1352733527     27.0          0          00270001  2012-11-12
# 2156967  1352733547     27.0          0          00270001  2012-11-12
# 2157111  1352733566     27.0          0          00270001  2012-11-12
# 2157203  1352733586     27.0          0          00270001  2012-11-12
# 2157343  1352733607     27.0          0          00270001  2012-11-12
# 2157499  1352733628     27.0          0          00270001  2012-11-12
# 2157575  1352733646     27.0          0          00270001  2012-11-12
# 2158058  1352733726     27.0          0          00270001  2012-11-12
# 2158555  1352733806     27.0          0          00270001  2012-11-12
# 2159294  1352733927     27.0          0          00270001  2012-11-12
# 2159845  1352734007     27.0          0          00270001  2012-11-12
# 2155470  ('15:15:07', 'Monday')          0
# 2155599  ('15:15:28', 'Monday')         21
# 2155711  ('15:15:46', 'Monday')         39
# 2155833  ('15:16:07', 'Monday')         60
# 2155974  ('15:16:29', 'Monday')         82
# 2156083  ('15:16:46', 'Monday')         99
# 2156345  ('15:17:29', 'Monday')        142
# 2156489  ('15:17:47', 'Monday')        160
# 2156583  ('15:18:08', 'Monday')        181
# 2156706  ('15:18:26', 'Monday')        199
# 2156853  ('15:18:47', 'Monday')        220
# 2156967  ('15:19:07', 'Monday')        240
# 2157111  ('15:19:26', 'Monday')        259
# 2157203  ('15:19:46', 'Monday')        279
# 2157343  ('15:20:07', 'Monday')        300
# 2157499  ('15:20:28', 'Monday')        321
# 2157575  ('15:20:46', 'Monday')        339
# 2158058  ('15:22:06', 'Monday')        419
# 2158555  ('15:23:26', 'Monday')        499
# 2159294  ('15:25:27', 'Monday')        620
# 2159845  ('15:26:47', 'Monday')        700
# 2160370  ('15:28:06', 'Monday')        779
# 2161186  ('15:30:06', 'Monday')        899
# 2161656  ('15:31:28', 'Monday')        981
# 2164127  ('15:38:10', 'Monday')       1383
# 2164525  ('15:39:07', 'Monday')       1440
# 2164875  ('15:39:48', 'Monday')       1481
# 2165367  ('15:41:09', 'Monday')       1562
# 2167218  ('15:45:31', 'Monday')       1824
# 2167590  ('15:46:30', 'Monday')       1883
# ...                         ...        ...
# 2184971  ('16:26:43', 'Monday')       4296
# 2185687  ('16:28:23', 'Monday')       4396
# 2186884  ('16:30:46', 'Monday')       4539
# 2187139  ('16:31:25', 'Monday')       4578
# 2187752  ('16:32:43', 'Monday')       4656
# 2188944  ('16:35:13', 'Monday')       4806
# 2190211  ('16:37:51', 'Monday')       4964
# 2192335  ('16:42:32', 'Monday')       5245
# 2193068  ('16:44:12', 'Monday')       5345
# 2195710  ('16:49:54', 'Monday')       5687
# 2196292  ('16:51:12', 'Monday')       5765
# 2197608  ('16:54:12', 'Monday')       5945
# 2197777  ('16:54:33', 'Monday')       5966
# 2200717  ('17:00:12', 'Monday')       6305
# 2202496  ('17:03:52', 'Monday')       6525
# 2203119  ('17:05:12', 'Monday')       6605
# 2204500  ('17:07:54', 'Monday')       6767
# 2204652  ('17:08:13', 'Monday')       6786
# 2206133  ('17:11:12', 'Monday')       6965
# 2206314  ('17:11:35', 'Monday')       6988
# 2206914  ('17:12:53', 'Monday')       7066
# 2207742  ('17:14:32', 'Monday')       7165
# 2207895  ('17:14:53', 'Monday')       7186
# 2208034  ('17:15:11', 'Monday')       7204
# 2208213  ('17:15:32', 'Monday')       7225
# 2208987  ('17:17:12', 'Monday')       7325
# 2209472  ('17:18:12', 'Monday')       7385
# 2211377  ('17:22:11', 'Monday')       7624
# 2211852  ('17:23:13', 'Monday')       7686
# 2212987  ('17:25:33', 'Monday')       7826
#
# [80 rows x 19 columns]

# %% [markdown]
# ## Data Analysis Based on H1 from Data Analytics Module

# %%
df.shape
# Out:
# (2298944, 19)
